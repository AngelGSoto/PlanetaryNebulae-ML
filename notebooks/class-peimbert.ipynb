# %%
import pandas as pd
from astropy.table import Table

# %%
df = pd.read_csv("../class-pne-peimbert.csv")

# %%
df
# Out:
#      recno     Name         PNG   He/H n_He/H    r_He/H  lg(O/H)+12  \
# 0        1       A4  144.3-15.5    NaN               21         NaN
# 1        2      A12  198.6-06.3  0.119                3        8.93
# 2        3      A18  216.0-00.2  0.152                3        7.99
# 3        4      A20  214.9+07.8  0.125                3        8.80
# 4        5      A24  217.1+14.7    NaN               21         NaN
# ..     ...      ...         ...    ...    ...       ...         ...
# 471    472    Vy2-1  007.0-06.8  0.145                6        8.94
# 472    473    Vy2-2  045.4-02.7  0.104         13,21,23        8.34
# 473    474   Y-c2-5  240.3+07.0  0.071                3        9.05
# 474    475  Y-c2-32  013.7-10.6  0.088                6        8.59
# 475    476     Ym29  205.1+14.2    NaN               16        8.53
#
#     r_lg(O/H)+12  lg(N/H)+12 r_lg(N/H)+12  ...  p(typeI)  p(typeIIa)  \
# 0             21         NaN           21  ...      0.00        0.00
# ...
